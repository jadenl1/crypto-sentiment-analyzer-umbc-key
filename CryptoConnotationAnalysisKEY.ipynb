# %% [markdown]
# # Twitter-Crypto Popularity Predictor
# ## 10/30/21
# ## By: Jaden L, Nishith S, Satvik R, & Rohan B

# %% [markdown]
# ## i. Boiler Plate, authorization

# %%
import tweepy as twp
from textblob import TextBlob

from dotenv import load_dotenv
import os

load_dotenv()

#consumer keys
API_KEY = "4084w6OgZgpfCPokKiptoOu0d"
API_KEY_SECRET = "0hoOMwSSWtk1A3MpEz8DnvHldwBeQILWHPAKH3urzqeM1NXbRA"
#other
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAACofVQEAAAAA37oDeWUoJjHHjFGcZIB7Hczsxbw%3Dq9faBKvvgAcnkTycCSEg0VnzkloiQJMmGNhBQFRiwYOrwgcaIw"
ACCESS_TOKEN = "1454477188669923332-emJUzrZpc7De5Oe8VjV4WFc2hcKN33"
ACCESS_TOKEN_SECRET = "O5kSDeMZMyxTfEcSTSe6ySOSog3tSio4NO3q0Ud3HQxi0"


auth = twp.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = twp.API(auth)

# %% [markdown]
# ## ii. Finding Connotation

# %%
# My Functions

def getPolarity(tweet):
    #return TextBlob.sentiments.(tweet)
    return TextBlob(tweet).sentiment.polarity


def getSentiment(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'


def find_account_value(tweet):
    #check verification
    #check followers
    value = 1
    ver = tweet.user.verified
    if(ver == True):
        value *= 1.10
    elif(tweet.user.followers_count > 100000):
        value *= 1.05
    else:
        value += 0.05
    return value


#Fids value/impact of a single tweet
#param: tweet - item: full item of all data regarding current tweet
#param: list_of_tweets - int: a full list of tweets with all information regarding likes, user, retweets, etc.
def find_tweet_value(list_of_tweets, tweet):

    # getting tweet_likes
    tweet_likes = tweet.favorite_count
    tweet_rts = tweet.retweet_count

    #calculating averages
    total_likes = 0
    total_rts = 0
    for tweet in list_of_tweets:
        total_likes += tweet.favorite_count
        total_rts += tweet.retweet_count

    avg_likes = total_likes / len(list_of_tweets)
    avg_rts = total_rts / len(list_of_tweets)

    #initializing value
    value = 5
    
    #checking likes alt
    if tweet_likes > avg_likes:
        value += tweet_likes / avg_likes
    elif tweet_likes < avg_likes:
        value -= tweet_likes / avg_likes

    #checking retweets
    if tweet_rts > avg_rts:
        value += tweet_rts / avg_rts
    elif tweet_rts < avg_rts:
        value -= tweet_rts / avg_rts

    
    return value


def getMagnitude(list_of_tweets, tweet):
    pol = getPolarity(tweet.text)
    sen = getSentiment(pol)

    mag = 0

    if(sen == "Negative"):
        mag = find_account_value(tweet) + find_tweet_value(list_of_tweets, tweet) * -1
    elif(sen == "Neutral"):
        mag = 0
    else:
        mag = find_account_value(tweet) + find_tweet_value(list_of_tweets, tweet)
    
    return mag


def getConnotation(list_of_tweets):
    con = 0
    for tweet in list_of_tweets:
        con += getMagnitude(list_of_tweets, tweet)
    return con


#loops through tweets and prints all information regarding tweet
#param: list_of_tweets - int: a full list of tweets with all information regarding likes, user, retweets, etc.
def print_all_tweets(list_of_tweets):

    for tweet in list_of_tweets:
        tweet_value = find_tweet_value(list_of_tweets, tweet) #finding tweet value
        acc_value = find_account_value(tweet) #finding account value
        magnitude = getMagnitude(list_of_tweets, tweet)
        print(f"Verified: {tweet.user.verified}")
        print(f"{tweet.user.screen_name} tweeted: ") #prints username
        print("-----")
        print(tweet.text) #prints actual tweet text
        print("-----")
        print(f"# of likes: {tweet.favorite_count}") #prints likes
        print(f'# of retweets: {tweet.retweet_count}') #prints retweets
        print(f"Tweet Value: {tweet_value}") #prints tweet value
        print(f"Account Value: {acc_value}") #prints account value
        print(f"Tweet Magnitude: {magnitude}")

        #getting sentiment
        pol = getPolarity(tweet.text)
        sen = getSentiment(pol)
        print(f"Sentiment: {sen}") #prints sentiment
        
        print("-------------------------------------------------------------------------------") #seperates each tweet


#main function
def main():
    # user input
    user_search = input("What coin are you looking for? ")
    search_term = user_search + " -filter:retweets"

    # making a list of all tweets with my query
    search_tweets = api.search_tweets(q = search_term, lang = "en", count = 100000, result_type = "mixed")
    

    # shows me how many tweets api.search_tweets() gets
    print(user_search.upper())
    print(f"Number of tweets found: {len(search_tweets)}")
    print("------------------------------------------------------------------------------------------------------------------------")

    # loops through each tweet in search_tweets and prints information about each tweet
    print_all_tweets(search_tweets)
    
    connotation = getConnotation(search_tweets)
    print(f"CURRENT CONNOTATION: {connotation}")


main()
# Out:
# BITCOIN
# Number of tweets found: 100
# ------------------------------------------------------------------------------------------------------------------------
# Verified: True
# jack tweeted:
# -----
# is there a more honest market than Bitcoin?
#
# (obviously I don't think so)
# -----
# # of likes: 29936
# # of retweets: 3500
# Tweet Value: 63.5432041538899
# Account Value: 1.1
# Tweet Magnitude: 64.6432041538899
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: True
# CashApp tweeted:
# -----
# 👻 We’re giving away $20,000 today in bitcoin and cash. Share this post with your $Cashtag for a chance to win $100,… https://t.co/rqIZ1tjaQk
# -----
# # of likes: 29354
# # of retweets: 14628
# Tweet Value: 117.96853747361729
# Account Value: 1.1
# Tweet Magnitude: 119.06853747361728
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: True
# JoePompliano tweeted:
# -----
# El Salvador made Bitcoin legal tender 54 days ago.
#
# More citizens now have Bitcoin wallets than traditional bank ac… https://t.co/Rml5PpEUTR
# -----
# # of likes: 13408
# # of retweets: 2019
# Tweet Value: 33.46099158453074
# Account Value: 1.1
# Tweet Magnitude: 34.56099158453074
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# ajturner tweeted:
# -----
# @stevage1 I believe in the future of AR &amp; VR as meaningful methods for learning, communication, games.
#
# FB sent a… https://t.co/2b1yw8xOIc
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# crypto_mum_ tweeted:
# -----
# #bitcoin white paper published 13 yrs ago today …. How the world has changed. Proud to know 1 person in particular… https://t.co/ekflImAK3d
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# eh_dagg tweeted:
# -----
# @weaverology @dervish2115 @Snowden @joel_schectman So how exactly will they enforce that? I opt out by using bitcoi… https://t.co/LcAsJPMbj5
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# lizzybholly tweeted:
# -----
# @AlgoYooshi Great project
#
# @aminebwe @MatanmiSalami @Tunde99916400
#
# #YooShifamily#ALGO#Bitcoin#Algorand#nftart#GAMINGNFT
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# PenisNuts tweeted:
# -----
# Bitcoin Keeps Messing Up The Controls
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# NguyenNincy tweeted:
# -----
# @AirdropStario I am following this project, hopefully it will be an extraordinary asset choice in the future and ca… https://t.co/2bmXr7pIwF
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# galdos_ben tweeted:
# -----
# @CiaraHuobi We are ready 🐾🐶🦾
#
# @BabyDogeCoin @elonmusk #BabyDogeCoin #charity #donation #savingdogs 🐾🐶 #card 💳… https://t.co/OaJ0uPeCHy
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.99862461661188
# Account Value: 1.05
# Tweet Magnitude: 6.04862461661188
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# black_kass tweeted:
# -----
# Wow! As I was taking the subway in Lisbon, I stumbled upon this! 👀😬
# #NEARProtocol
# Cryptocurrency adoption is just… https://t.co/FCn4c1sOlQ
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# HobaBot tweeted:
# -----
# 🚀🚀🚀 $NEO Long Position(v2) 🚀🚀🚀
#
# Entry: 45.958
# Target:46.179
# Stop:45.489
#
# #Binance #Bitcoin #Signals #Buy #NEOUSDT #NEO
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.99862461661188
# Account Value: 1.05
# Tweet Magnitude: -3.9486246166118804
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# Adriandelpapa tweeted:
# -----
# @BITCOIN_ANIMALS IT´S AN ARTWOK THAT FINNALLY WAS FINISHED AFTER 11 YEARS OF LOVING WAITING.THIS SEQUENCE SHOWS HER… https://t.co/TYjoamEBB0
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# PaulDFitzgeral1 tweeted:
# -----
# @MissBeck12 @DrShaneRRR I donate blood. I think I’ll just hold on to it as my unvaccinated blood will be worth more… https://t.co/OOKGpBevwu
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# layorlahot tweeted:
# -----
# @AlgoYooshi I’m happy for this opportunity to be part of this project I’m very Thanks for this great opportunity, I… https://t.co/uoWpMvPIMM
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# jhengstler tweeted:
# -----
# And you thought forgetting your Apple ID, Netflix or Amazon password was a hassle—at least you could get a password… https://t.co/pRYkRt0bMv
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# drugaCig tweeted:
# -----
# @AlgoYooshi come here my brader @dust2dust__ @chomnivora @benyamin158
#
# #halloween2021 #Bitcoin #AirdropKing… https://t.co/FDZCv8hKLx
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# clini_que tweeted:
# -----
# Best project ever, I am very happy to be participating in this project. I hope this project will gain more populari… https://t.co/KboVJnGc8J
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Suheb__ tweeted:
# -----
# HODL on to your #Bitcoin on chain with *your* private keys in *your* custody. https://t.co/aW9x78aZu8
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# bitharington tweeted:
# -----
# The word "Bitcoin" only appears in the title and website url of the Satoshi white paper, not in the text itself. Al… https://t.co/MTq8Dkdm1H
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# DeepBlueCrypto tweeted:
# -----
# 8/
#
# The day of Halloween 👻 🎃 in 2009 Satoshi Nakamoto released the 9 page white paper for “Bitcoin: A Peer-2-Peer E… https://t.co/MmDiUdXN0M
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# a_bitcoin_pleb tweeted:
# -----
# @dohertym12 @MetalGearVapor @dergigi And on public transport. Some small shop owners ask you to wear mask bcs they… https://t.co/6BVaLTV2vf
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# holorevolution tweeted:
# -----
# $HOT #Holo #Holochain 🔥
#
# Web 3.0; NextNet; The Next Internet; A revolution in DLT; The step after #Blockchain;
#
# wha… https://t.co/33vUJaOb2e
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.99862461661188
# Account Value: 1.05
# Tweet Magnitude: 6.04862461661188
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# iBrokeTheMatrix tweeted:
# -----
# https://t.co/72KYSesoZE
# BITCOIN, the best asset you can buy and hold for the next 100 years. This video made me rea… https://t.co/U8eFsjrmmr
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# dajennison tweeted:
# -----
# @Forbes Guarantee, a Bitcoin Billionaires PAC see the year 2024 completely different than a current Administration!… https://t.co/KBHqdYVjyF
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# clini_que tweeted:
# -----
# @CryptoNetwork22 Best project ever, I am very happy to be participating in this project. I hope this project will g… https://t.co/MXoLMY0jC9
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Igor0637 tweeted:
# -----
# @Cloverxoxo1 @RaethHollow Furry art for Bitcoin weirdos
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# PolarisAuroraa tweeted:
# -----
# #Bitcoin could correct between $57,623 and $59,016. The forecast is that the value may initially recover the resist… https://t.co/95yt2bVXxs
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# hesoyam_op tweeted:
# -----
# @AlgoYooshi An excellent project with very good potential and fundamentals. I hope to be included in the participat… https://t.co/bOZj9mrgXX
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.99862461661188
# Account Value: 1.05
# Tweet Magnitude: 6.04862461661188
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# GutterScreen tweeted:
# -----
# #Better with #Bitcoin . The white paper to read should be all over #Bitcoin Twitter today. It's the 13th anniversar… https://t.co/PRg6pOiXxF
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# mdgesun6 tweeted:
# -----
# @airdropinspect Good project sir
#
# @BangunArya6
# @Rofeq_cok
# @ARIFSU12345
#
# #Airdrop #Airdrops #Airdropinspector #BSC… https://t.co/TtZ9BEDpJg
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# expnfts tweeted:
# -----
# gm bitcoin white paper happy 13th https://t.co/b3zBpt5WTx
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# clini_que tweeted:
# -----
# Best project ever, I am very happy to be participating in this project. I hope this project will gain more populari… https://t.co/33LTm8HY4Q
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Richcrown6193 tweeted:
# -----
# @AlgoYooshi This is great news I'm happy to be among the participants.
# @Rich_moore619
# @AriyoAdeyemi1… https://t.co/JSZ6OZ4DSZ
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# ripon_nabi tweeted:
# -----
# @airdropinspect Excellent project, i hope it will be one of the best project in the airdrop history. I am really ha… https://t.co/pVddhq8kul
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# EndGame2100 tweeted:
# -----
# @maternus #bitcoin fixes this
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# IoPfaa tweeted:
# -----
# @laomaopai @dragonkart Despite these pullback we’ve had not quite long am still confident #Bitcoin sees another hig… https://t.co/zC5RiU98Tr
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# rajuchavda1981 tweeted:
# -----
# ..system which should affect #equities #bitcoin #nifty
#
# But one can’t ignore strong seasonality factor where Nov/D… https://t.co/DnhkAP5M4R
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# TracyLawman tweeted:
# -----
# You need to wake up from your slumber
# You should also know that $BTC is here to stay and you can make enough incom… https://t.co/BEkH59juAb
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# bmurphypointman tweeted:
# -----
# #digitalmarketing #tumblr #twitter #facebook #instagram #dogecoin #socialmedia #pinterest #doge #deal #gift #gifts… https://t.co/mylv5kTxfP
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# bmurphypointman tweeted:
# -----
# #income #jobs #affiliateprogram #affiliatemarketing Check my #website #makemoney #earnmoney #affiliate #referral… https://t.co/VLbdI2ve3Y
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# bmurphypointman tweeted:
# -----
# #present #linkedin #twitter #facebook #instagram #dogecoin #socialmedia #pinterest #doge #deal #gift #gifts… https://t.co/oalSEvWEUc
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# RandyBTC2000 tweeted:
# -----
# #Bitcoin  Happy Whitepaper day..
# Thank you Satoshi Nakamoto.. Ho ever you are 🦊❤ https://t.co/bGxYMegxn8
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.99862461661188
# Account Value: 1.05
# Tweet Magnitude: 6.04862461661188
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# ahmadyani_97 tweeted:
# -----
# @airdropinspect Excellent project, i hope it will be one of the best project in the airdrop history. I am really ha… https://t.co/G6TYzB29LK
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.99862461661188
# Account Value: 1.05
# Tweet Magnitude: 6.04862461661188
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# JodieFerdinand7 tweeted:
# -----
# @AmeerRosic #bitcoin weekly Close above this level would confirm a break of this final major resistance area at $60… https://t.co/LwLFUZRFqK
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Flemishman79 tweeted:
# -----
# @OTC_Bitcoin Well, its not really 300$ because of pump, its because of supply , for example coin Mfund,  it was aro… https://t.co/5KFRK891rd
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# attorneysanders tweeted:
# -----
# Most of my adult life I’ve told people "Happy Reformation Day" today in honor of Martin Luther‘s 95 theses being po… https://t.co/plwjytII36
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# IoPfaa tweeted:
# -----
# @jamesvgingerich Despite these pullback we’ve had not quite long am still confident #Bitcoin sees another high this… https://t.co/bcO979VFBp
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# hsoto tweeted:
# -----
# @natceeney @thetimes Jamie Dimon of JP Morgan, saying “I personally think that bitcoin is worthless”, the Bank of E… https://t.co/YvMTsumTnS
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# CoinTrendz tweeted:
# -----
# 📈Pump Alert! - FKX/USDT on Kucoin! Price increase: 5.38% | Volume: +24.57%
# $FKX $USDT #kucoin #crypto #bitcoin… https://t.co/mO3BV2A6wa
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# 360mediaX tweeted:
# -----
# Two of the biggest bitcoin mining companies in the world are battling it out in a Texas town of 5,600 people https://t.co/eWa0gFUqRL
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Jaynwigbo tweeted:
# -----
# @AlgoYooshi This is a very good and amazing project and i believe it will succeed massively
#
# @ademuyken111… https://t.co/uvCAZW3ArR
# -----
# # of likes: 1
# # of retweets: 1
# Tweet Value: 4.993661837455552
# Account Value: 1.05
# Tweet Magnitude: 6.043661837455552
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Alert_Shark tweeted:
# -----
# #Bitcoin 📉
#
# ▓▓▓▓▓▓▓▓▓░░░░░░ 61%
#
# price:$60231.76      eth/btc: 0.07
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# mrshell999 tweeted:
# -----
# Simple classify KOLs in crypto:
# People with sense of humor discuss @Doge,@Shib
# People who always be fooled discuss… https://t.co/iKPSjk8kPY
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# CryptoGazette tweeted:
# -----
# Fine Art NFTs: 100% Decentralized Community Experiment Art Token Metti Inu https://t.co/hS5p56LzA5 #defi20 #ohm #bitcoin #crypto
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# IT_Farhan tweeted:
# -----
# @piramida @PeterSchiff Aluminum is nothing like gold… why is Bitcoin so much better than other cryptos
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Smith28301 tweeted:
# -----
# How to make money?
# Work and buy $SHIB
#
# #BTC #BITCOIN $DOT $KSM $ETH $MATIC $ADA $XRP $BNB $TRX $LUNA $UNI $CAKE… https://t.co/0HEhzvhHkX
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Nakadai_mon tweeted:
# -----
# If you don't have your own private keys you don't hodl #bitcoin. Many people will learn this harsh lesson. Especial… https://t.co/XCe1ZdeTOr
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.99862461661188
# Account Value: 1.05
# Tweet Magnitude: 6.04862461661188
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Gnet_Ekong tweeted:
# -----
# @AlgoYooshi Nice project
#
# @BaziSavvy @KeliCallaghan @edet_jessie
#
# #halloween2021 #Bitcoin #AirdropKing #Airdrops… https://t.co/0XPyN5SmMa
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# endinkalem tweeted:
# -----
# @airdropinspect This is a really great and excellent project 👏
# Thank you for the opportunity. I hope this project… https://t.co/CGZnKbtirC
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# PyaeSoneAg10 tweeted:
# -----
# @CryptoNetwork22 I fully support this great project and I believe there is no other project that is greater than th… https://t.co/ZTVYThqAIo
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Alex343 tweeted:
# -----
# @zndtoshi @w_s_bitcoin @BittrexExchange Never heard of her. Lmfao
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# 79_bitcoin tweeted:
# -----
# @Bitcoinsensus Yes sir!
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# EnrichedFeed tweeted:
# -----
# Where Bitcoin Fits in a Post-Scarcity World | CRYPTO
# The post Where Bitcoin Fits in a Post-Scarcity World appeared… https://t.co/MU3IOb2bTm
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# OnChainCollege tweeted:
# -----
# #Bitcoin’s 13th birthday on Halloween 👀 👻 🎃
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Ocha918_NFT tweeted:
# -----
# Chain: Polygon
# App : OpenSea
# Buy now
# 0.05 ETH
#
# https://t.co/qv5LyDPiBA
#
# #polygonNFT #PolygonSpace #NFTTHAILAND… https://t.co/mgF8r5yMIp
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Honest_Sy1 tweeted:
# -----
# @Nordes__ Do you know why bitcoin had reached its all going high but VEchain hasn't?
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# JodieFerdinand7 tweeted:
# -----
# @ZabAkbar @TheMikeStillUK #bitcoin weekly Close above this level would confirm a break of this final major resistan… https://t.co/erSumGwCzD
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# moch_devid tweeted:
# -----
# @AlgoYooshi I am so excited about this project. I believe this will be a solid project and no one should endeavor t… https://t.co/w3boUi7pts
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# kellysiqili tweeted:
# -----
# #CRYPTOCURRENCIES are MOVING! Try https://t.co/1fbsW58g32 to scan for #altcoin and #bitcoin movements.
#
# #BTC #ETH… https://t.co/3QAc5Qm0kd
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# therealpreneur_ tweeted:
# -----
# Two of the biggest bitcoin mining companies in the world are battling it out in a Texas town of 5,600 people https://t.co/sRlPUHa5Ee
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# haru0191 tweeted:
# -----
# @AirdropStario A good project and strong team. I think in the near future we will see an unprecedented growth of th… https://t.co/dn1l3MBMKx
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# good44411 tweeted:
# -----
# @DeflyBall Just imagine if we invest a little of our money here and the increase or trend is very fast cuan is comi… https://t.co/13GVQHsnyb
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# cantrillion tweeted:
# -----
# Sunday reading.. The 13th anniversary of the Bitcoin white paper is today. Never too late to start learning! https://t.co/QC4Evc0CMQ
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# agon56532612 tweeted:
# -----
# @TheRuneRanger if only bitcoin would have moved todays we should have seen 16 dollars
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# CryptoHuntersOF tweeted:
# -----
# Check this week's cryprocurrency news in our latest article:
#
# https://t.co/obNlqJEX1p
#
# #Crypto #Trading #Signals #Bitcoin
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Lakers_ftw_ tweeted:
# -----
# @PeterSchiff @saylor Bitcoin applying pressure
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# JahangirShelim tweeted:
# -----
# @airdropinspect Excellent project, i hope it will be one of the best project in the airdrop history. I am really ha… https://t.co/nafbSeyiSK
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# CardanoNFT tweeted:
# -----
# As for #Bitcoin it might pullback towards the 1D MA50 ($53K) to complete the C&amp;H pattern and then rebound to make N… https://t.co/6kPc7FinDo
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# _SirMurphy tweeted:
# -----
# @AlgoYooshi This project is going to be huge in Algo ecosystem 🔥🔥 let's moon together guys 🔥
#
# @ayakaterver… https://t.co/Hr32OiBWA9
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# JodieFerdinand7 tweeted:
# -----
# @bitcoinagile #bitcoin weekly Close above this level would confirm a break of this final major resistance area at $… https://t.co/Sx9REQkq0l
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# DonCryptonn tweeted:
# -----
# ✅How has the Bitcoin exchange rate changed over the past 5 years https://t.co/swKFNnBMUE
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# PolarisAuroraa tweeted:
# -----
# Bitcoin Is Still Fine Towards $90k, Says Crypto Expert - https://t.co/EINrVCXw6w
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# bitcoincorda tweeted:
# -----
# @AndreasSteno @IoGitm @MichaelAArouet @Bruw50 It is important to not lose your first principles thinking. If there… https://t.co/gkHGnb9wz6
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# TeamSatoshi tweeted:
# -----
# Open a digital wallet &amp; run a node of your favorite fork of Bitcoin.
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# CryptoJuanan tweeted:
# -----
# @pronewchaos @bitcicomglobal @bitcicom @BitciFanToken @coingecko Yes 😂😂 is so confused totally agree with you 😂 fir… https://t.co/uFVMijhISc
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# cryptoalerts911 tweeted:
# -----
# The Billion-Dollar Bitcoin Case: Long-Awaited Kleiman v. Wright Trial Begins Next Week in Miami || #CryptoNews… https://t.co/9iCodmP2Gi
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# FreePalestBot tweeted:
# -----
# Crypto Prices (USD/₿)
#
# Bitcoin ⇨ $60378.3395➷
# AxieInfinity ⇨ $134.8655➷
# VeChain ⇨ $0.1281➷
# EthereumClassic ⇨ $47.56… https://t.co/OjoZiYR93Y
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# 47__Khalifa tweeted:
# -----
# Good News For Revolotto holders
# #Revolotto
# #Bitcoin
# #cryptocurrency https://t.co/Z1NPURZzMq
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# DerekTMcKinney tweeted:
# -----
# 🤓🤔👍 #knownews #AMBCrypto #bitcoin #bnb #CryptoCurrency #ethereum #xrp XRP, Dogecoin, BAT Price Analysis: 31 October  https://t.co/PVOBWsNZ3k
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# oncefuturebrand tweeted:
# -----
# Abstract. A purely peer-to-peer version of electronic cash would allow online payments to be sent directly from one… https://t.co/uhgm5418Ro
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# DaoThanhVan6 tweeted:
# -----
# @airdropinspect Participated with trust in, thanks #ZecreyProtocol and #airdropinspect for me the chance in this gr… https://t.co/W9sGOfTltO
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# InvestWithDiego tweeted:
# -----
# Understanding the Bitcoin Whitepaper with @kurtwuckertjr
#
# https://t.co/tUCYK4jsoN
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# MR_Carl_P tweeted:
# -----
# Two of the biggest bitcoin mining companies in the world are battling it out in a Texas town of 5,600 people https://t.co/wfIdDm8GDP
# -----
# # of likes: 1
# # of retweets: 1
# Tweet Value: 4.993661837455552
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Demooriginal9 tweeted:
# -----
# @MoonTimerGame The project is implemented professionally and has a clear development plan. Made by a very professio… https://t.co/t1twrp8Sfb
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# NurOfficial03 tweeted:
# -----
# @airdropinspect Woow amazing project and it is going to be the best project of the year. The team is very hard work… https://t.co/lZmF8owlXX
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# ConradBecker9 tweeted:
# -----
# Despite the sideways trend, one thing that stood out during the last week was the fact that Bitcoin futures ETFs we… https://t.co/HbdTJSf48G
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# MyCryptoFire tweeted:
# -----
# "Sources Say Valkyrie Bitcoin Strategy ETF Set to Launch on Nasdaq This Week – Finance Bitcoin News"… https://t.co/2leESBknHt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# bitcoin_nj tweeted:
# -----
# @hashing2heating 🙏🙏 The giveaway is only a few weeks from now. Subscribe today for a chance to win 🙌
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Bot11031 tweeted:
# -----
# Crypto Prices (USD/₿)
#
# Bitcoin ➽ $60378.3395➷
# BitcoinCash ➽ $582.8897➷
# Polygon ➽ $1.8202➷
# Filecoin ➽ $64.3798➷
# Stel… https://t.co/TlVEVZyxGg
# -----
# # of likes: 0
# # of retweets: 1
# Tweet Value: 4.995037220843672
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# CURRENT CONNOTATION: 513.3595181325536
